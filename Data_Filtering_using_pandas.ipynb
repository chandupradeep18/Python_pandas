# %% [markdown]
# <a href="https://colab.research.google.com/github/chandupradeep18/Python_pandas/blob/main/Data_Filtering_using_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
sales=pd.read_csv('/content/drive/MyDrive/Data Sources/amazon_sales.csv')
parquet=pd.read_parquet('/content/drive/MyDrive/Data Sources/results.parquet')

# %%
sales.columns #
sales.shape
sales.info()
sales.describe()

# %%
sales.head()
sales.tail()
sales.sample(10)

# %%
sales.loc[9018]
sales.loc[9018,['product_title','product_rating','original_price']]
sales.loc[9018,'product_title']
sales.loc[9018:9324,'product_title']

# %%
sales.iloc[9018]
sales.iloc[9018,[1,2,3,4]]
sales.iloc[9018,2]
# Out:
# np.float64(2740.0)

# %%
print(sales.loc[9018:9100:5,['product_rating','product_category']])
sales.loc[9023,'product_rating']=4.6
print(sales.loc[9018:9100:5,['product_rating','product_category']])
sales.loc[9018:9100:5]

# %%
sales.at[9023,'product_rating']
sales.iat[9023,0]
# Out:
# 'AMD Ryzen™ 9 7950X3D 16-Core, 32-Thread Desktop Processor'

# %%
for i in sales.iterrows():
  print(i)
  break

# %%
sales.sort_values(['data_collected_at','product_rating','product_category'],ascending=True)

# %%
#filting Condition
sales.loc[(sales['product_rating']<4.0) & (sales['is_best_seller']=='Best Seller')]
print(parquet.columns)
parquet[(parquet['year'].between(2000,2026)) & (parquet['place'].isin([1,2,3])) & (parquet['type']=='Summer') & (parquet['event'].str.contains('Men')) & (parquet['medal'].isin(['Gold'])) | (parquet['type']=='Winter') & (parquet['event'].str.contains('Women')) & (parquet['medal'].isin(['Gold']))]
# Out:
# Index(['year', 'type', 'discipline', 'event', 'as', 'athlete_id', 'noc',
#        'team', 'place', 'tied', 'medal'],
#       dtype='object')
#           year    type                           discipline  \
# 850     2000.0  Summer                              Archery
# 1897    2000.0  Summer                               Tennis
# 1904    2000.0  Summer                               Tennis
# 2285    2004.0  Summer                            Badminton
# 2295    2004.0  Summer                            Badminton
# ...        ...     ...                                  ...
# 307362  2022.0  Winter                Bobsleigh (Bobsleigh)
# 307868  2022.0  Winter  Short Track Speed Skating (Skating)
# 307873  2022.0  Winter  Short Track Speed Skating (Skating)
# 308090  2022.0  Winter        Cross Country Skiing (Skiing)
# 308092  2022.0  Winter        Cross Country Skiing (Skiing)
#
#                                           event                  as  \
# ...

# %%
parquet['details']=parquet['type']+" - "+parquet['medal']
parquet.sample(10)
# Out:
#           year    type                        discipline  \
# 288309  2020.0  Summer                           Fencing
# 131633  2000.0  Summer                           Sailing
# 284911  2016.0  Summer                              Golf
# 211887  1928.0  Winter              Ski Jumping (Skiing)
# 54480   1976.0  Summer  Artistic Gymnastics (Gymnastics)
# 37622   1924.0  Summer                           Fencing
# 305382  2020.0  Summer                            Karate
# 276486  2016.0  Summer                            Hockey
# 67285   1948.0  Summer  Artistic Gymnastics (Gymnastics)
# 99403   1972.0  Summer                 Diving (Aquatics)
#
#                                         event                  as  athlete_id  \
# 288309             Sabre, Team, Men (Olympic)       Eli Dershwitz      136303
# 131633              Multihull, Open (Olympic)      Santiago Lange       62704
# 284911              Individual, Men (Olympic)          Alex Čejka      134179
# ...

# %%
parquet.drop(columns=['details'],inplace=True)
parquet.sample()
# Out:
#           year    type           discipline                    event  \
# 282134  2016.0  Summer  Football (Football)  Football, Men (Olympic)
#
#                         as  athlete_id  noc       team  place   tied medal
# 282134  Santiago Ascacibar      132376  ARG  Argentina   11.0  False  None
